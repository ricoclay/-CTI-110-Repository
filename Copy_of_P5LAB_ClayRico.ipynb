# %% [markdown]
# <a href="https://colab.research.google.com/github/ricoclay/-CTI-110-Repository/blob/main/Copy_of_P5LAB_ClayRico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rico Clay
# 03-24-2025
# P5LAB
# Use of loops, functions and module import to complete assigment
# import the random libary to use in program
import random

def disperse_change(change):

    print()
    print(f"Change owed: ${change:.2f}")

    money = change

    # Convert money to a whole number
    money = round(money * 100)

    if money == 0:
        print("no change")

    '''
    # May need to round this value
    money = round(money * 100)


    print(money)
    '''

    # Get whole dollars from money amount
    dollars = money // 100

    # Remove the dollar amount from money
    money = money - (dollars * 100)

    '''print(f"Dollars: {dollars}")'''

    # Get quarters from money amount
    quarters = money // 25

    # Remove the quarter amount from money
    money = money - (quarters * 25)

    '''print(f"Quarters: {quarters}")'''
    # Get dimes from money amount
    dimes = money // 10

    # Remove the dimes amount from money
    money = money - (dimes * 10)

    '''print(f"Dimes: {dimes}")'''
    # Get nickles from money amount
    nickles = money // 5

    # Remove the nickles amount from money
    money = money - (nickles * 5)

    '''print(f"Nickles: {nickles}")'''

    # Get pennies from money amount
    pennies = money // 1

    # Remove the pennies amount from money
    money = money - (pennies * 1)

    '''print(f"Pennies: {pennies}")'''

    # Diplay number of follars and coins needed
    if dollars >= 1:
        if dollars == 1:
            print(f"{dollars} dollar")
        else: # More than one
            print(f"{dollars} dollars")
    # Diplay number of follars and coins needed
    if quarters >= 1:
        if quarters == 1:
            print(f"{quarters} quarter")
        else: # More than one
            print(f"{quarters} quarters")
    # Diplay number of follars and coins needed
    if dimes >= 1:
        if dimes == 1:
            print(f"{dimes} dime")
        else: # More than one
            print(f"{dimes} dimes")
    # Diplay number of follars and coins needed
    if nickles >= 1:
        if dollars == 1:
            print(f"{nickles} nickle")
        else: # More than one
            print(f"{nickles} nickles")
    # Diplay number of follars and coins needed
    if pennies >= 1:
        if dollars == 1:
            print(f"{pennies} pennie")
        else: # More than one
            print(f"{pennies} pennies")

# Define the main function
def main():
    print("Welcome to the store!")

    # Generate money owed
    owed = round(random.uniform(0.01, 100.00), 2)
    print(f"You owe ${owed:.2f}: ")

    inPut = float(input("How much cash will you put in the self-checkout? $"))
    change = inPut - owed
    # Rounds the change to the second decimal place
    change = round(change, 2)

    # Call the function to show the change as coins
    disperse_change(change)

# Call the main
if __name__ == "__main__":
    main()
# Out:
# Welcome to the store!
# You owe $18.49:
# How much cash will you put in the self-checkout? $20
#
# Change owed: $1.51
# 1 dollar
# 2 quarters
# 1 pennie
